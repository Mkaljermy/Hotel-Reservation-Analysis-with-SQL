# %%
import pandas as pd 
from sqlalchemy import create_engine

# %%
data = pd.read_csv("Hotel Reservation Dataset.csv")

# %%
data
# Out:
#     Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights
# 0     INN00001             2               0                     1  \
# 1     INN00002             2               0                     2
# 2     INN00003             1               0                     2
# 3     INN00004             2               0                     0
# 4     INN00005             2               0                     1
# ..         ...           ...             ...                   ...
# 695   INN00696             2               0                     0
# 696   INN00697             2               0                     2
# 697   INN00698             2               0                     2
# 698   INN00699             2               0                     0
# 699   INN00700             2               1                     0
#
#      no_of_week_nights type_of_meal_plan room_type_reserved  lead_time
# 0                    2       Meal Plan 1        Room_Type 1        224  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Booking_ID            700 non-null    object
#  1   no_of_adults          700 non-null    int64
#  2   no_of_children        700 non-null    int64
#  3   no_of_weekend_nights  700 non-null    int64
#  4   no_of_week_nights     700 non-null    int64
#  5   type_of_meal_plan     700 non-null    object
#  6   room_type_reserved    700 non-null    object
#  7   lead_time             700 non-null    int64
#  8   arrival_date          700 non-null    object
#  9   market_segment_type   700 non-null    object
#  10  avg_price_per_room    700 non-null    float64
#  11  booking_status        700 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 65.8+ KB

# %% [markdown]
# *****************************************************************

# %% [markdown]
# ### Load data into database

# %%
engine = create_engine('postgresql://postgres:mdkn@localhost:5432/Mentorness')
#from sqlalchemy import create_engine
#engine = create_engine('postgresql://username:password@localhost:5432/mydatabase')

# %%
data.to_sql('hotel_reservation', engine, if_exists='replace', index=False)
# Out:
# 700
